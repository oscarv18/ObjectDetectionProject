# %% [markdown]
# # Exploring Parallel Computing Methods in Tensorflor
# By Oscar Vargas

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# ## Abstract
#
# Tensorflow is a machine learning platform that is popular amongst the autonomous vehicle community for its ability to accurately identify objects. This allows Tensorflow to detect objects in front of autonomous vehicles, giving the driver and/or vehicle time to make a decision. With one of Tensorflow's key applications being autonomous vehicles, using it to detect objects on train tracks is a logical next step.
#
# Rail is the most fuel-efficient way to move freight, taking cargo that would have taken over several hundred trucks to carry nearly 500 miles per  gallon of fuel on a single train. Despite this, of the 1.6 million railcars within the U.S, over 900,000 spend nearly 23 hours idling in train yards before being placed on the right tracks. This is a huge problem, especially considering that moving cargo by rail reduces greenhouse gas emissions by up to 75%.
#
# My goal is to build a real time object detection system to be used on locomotives in train yards to reduce the idling time of freight and reduce greenhouse gas emmissions.

# %% [markdown]
# ## Schedule
#
#  - **Feb. 5:** Project Proposal milestone due
#  - **Feb. 5 - Feb. 10:** Obtain and clean data
#  - **Feb. 13 - Feb. 17:** Create taxonomy of error types and analyze different models for consideration
#  - **Feb. 20 - Feb.24** Choose and modify model to fit needs
#  - **Feb. 26:** Project Part 1 due
#  - **Feb. 27 - March 3:** Test data against model, establish confidence intervals
#  - **March 6 - March 10:** Spring Break
#  - **March 13 - March 17:** Identify improvements to be made
#  - **March 20 - March 24:** Determine if automatic labeling will be implemented
#  - **March 27 - March 31:** Second round of testing and improvements
#  - **April 3 - April 7:** Third round of testing; all issues should be identified and resolved
#  - **April 10 - April 14:** Finalize model and prepare presentation
#  - **April 15:** Final project

# %% [markdown]
# ## Part 1: Software Exploration
#
# https://www.tensorflow.org/
#
# Tensorflow is an end-to-end machine learning platform that has a variety of uses, from performance monitoring and data automation to voice searching and image recognition. It uses an API to detect objects in images and videos and there even is a tutorial on how to use it. In fact, there is a multitude of tutorials available on Tensorflow's website that I will use to get a better understanding of how it works. In terms of hardware, I will be running experiment on the HPCC due to the sheer size of the data sets.

# %% [markdown]
# ## Part 2: Benchmark and Optimization
#
# I will be testing images of train tracks against the model, and thankfully Tensorflow already does support parallel computing methods. I will take advantage of this to see what kind of improvements can be made by running its object detection API in parallel. I will determine success with confidence intervals, which will be verified with human identification. In my final report I hope to deliver a detailed summary of what I learned and how I implemented that which I learned to create a polished product. As for success metrics, I am aiming at a 70% confidence interval in detecting. Should time allow, I plan to implement automatic labeling with confidence intervals, thus including object identification into the model.

# %% [markdown]
# ### References
#
# Image: https://www.mygreatlearning.com/blog/object-detection-using-tensorflow/
#
# https://www.aar.org/facts-figures#Economic-Impact
#
# https://www.freightwaves.com/news/economics-of-railcars-are-complex
#
# https://www.tensorflow.org/hub/tutorials/object_detection
#
# https://www.tensorflow.org/guide/distributed_training
